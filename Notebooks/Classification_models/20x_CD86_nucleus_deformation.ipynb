# %%
import pandas as pd
import sys
sys.path.append("../")
import macrophages_analysis
import os
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data import

# %%
preprocessed_data_path = '../../20x_datasets/Preprocessed_data/'

nucleus_dataset_p4g4 = pd.read_csv(preprocessed_data_path + 'clean_20x_CD86_P4G4_nucleus_dataset.csv')
nucleus_dataset_smooth = pd.read_csv(preprocessed_data_path + 'clean_20x_CD86_Smooth_nucleus_dataset.csv')
nucleus_dataset_tcps = pd.read_csv(preprocessed_data_path + 'clean_20x_CD86_TCPS_nucleus_dataset.csv')

# %% [markdown]
# # 20x CD86 P4G4 nucleus data
# ## 20x_CD86_p4G4_all_features

# %% [markdown]
# ## Train XGBClassifier

# %%
pipe_p4g4, test_data_p4g4 = macrophages_analysis.make_nucleus_classifier(nucleus_dataset_p4g4, confusion_matrix=True)
# Out:
# Mean accuracy of XGBClassifier (10-fold cross-validation) 0.8444705882352942
# Mean f1-macro of XGBClassifier (10-fold cross-validation) 0.8420131842853433
# Mean f1_weighted of XGBClassifier (10-fold cross-validation) 0.8425841922619979

# %% [markdown]
# ## One-vs-Rest multiclass ROC

# %%
macrophages_analysis.make_multiclass_roc(pipe_p4g4, test_data_p4g4)
# Out:
# AUC score for M1 0.9990079365079365
# AUC score for M2 0.9491548343475321
# AUC score for NT 0.9635149598249229
# Average AUC 0.9705592435601306

# %% [markdown]
# ## Get the most important features

# %%
important_features_smooth = macrophages_analysis.get_best_features(pipe_p4g4, nucleus_dataset_p4g4.drop('CellType', axis=1), 10)
fig, ax = plt.subplots(figsize=(10,5))
ax.barh(important_features_smooth['Feature'], important_features_smooth['Importance'], label='Feature Importance')
ax.legend()

# %% [markdown]
# # 20x CD86 Smooth nucleus data
# ## 20x_CD86_Smooth_all_features

# %% [markdown]
# ## Train XGBClassifier

# %%
pipe_smooth, test_data_smooth = macrophages_analysis.make_nucleus_classifier(nucleus_dataset_smooth, confusion_matrix=True)
# Out:
# Mean accuracy of XGBClassifier (10-fold cross-validation) 0.8929435483870968
# Mean f1-macro of XGBClassifier (10-fold cross-validation) 0.8898747195132982
# Mean f1_weighted of XGBClassifier (10-fold cross-validation) 0.89335977221127

# %% [markdown]
# ## One-vs-Rest multiclass ROC

# %%
macrophages_analysis.make_multiclass_roc(pipe_smooth, test_data_smooth)
# Out:
# AUC score for M1 0.9908482624649255
# AUC score for M2 0.9960870313037495
# AUC score for NT 0.9976763324780946
# Average AUC 0.9948705420822566

# %% [markdown]
# ## Get the most important features

# %%
important_features_smooth = macrophages_analysis.get_best_features(pipe_smooth, nucleus_dataset_smooth.drop('CellType', axis=1), 10)
fig, ax = plt.subplots(figsize=(10,5))
ax.barh(important_features_smooth['Feature'], important_features_smooth['Importance'], label='Feature Importance')
ax.legend()

# %% [markdown]
# # 20x CD86 TCPS nucleus data
# ## 20x_CD86_TCPS_all_features

# %% [markdown]
# ## Train XGBClassifier

# %%
pipe_tcps, test_data_tcps = macrophages_analysis.make_nucleus_classifier(nucleus_dataset_tcps, confusion_matrix=True)
# Out:
# Mean accuracy of XGBClassifier (10-fold cross-validation) 0.9428571428571428
# Mean f1-macro of XGBClassifier (10-fold cross-validation) 0.9304205492841309
# Mean f1_weighted of XGBClassifier (10-fold cross-validation) 0.9417441813281746

# %% [markdown]
# ## One-vs-Rest multiclass ROC

# %%
macrophages_analysis.make_multiclass_roc(pipe_tcps, test_data_tcps)
# Out:
# AUC score for M1 0.9956025883951235
# AUC score for M2 0.9922448979591837
# AUC score for NT 0.9981188358281153
# Average AUC 0.9953221073941408

# %% [markdown]
# ## Get the most important features

# %%
important_features_tcps = macrophages_analysis.get_best_features(pipe_tcps, nucleus_dataset_tcps.drop('CellType', axis=1), 10)
fig, ax = plt.subplots(figsize=(10,5))
ax.barh(important_features_tcps['Feature'], important_features_tcps['Importance'], label='Feature Importance')
ax.legend()
