# %%
import pandas as pd
import sys
sys.path.append("../")
import macrophages_analysis

# %% [markdown]
# ## Data import

# %%
preprocessed_data_path = '../../20x_datasets/Preprocessed_data/'

nucleus_dataset_p4g4 = pd.read_csv(preprocessed_data_path + 'clean_20x_CD206_P4G4_nucleus_dataset.csv')
nucleus_dataset_smooth = pd.read_csv(preprocessed_data_path + 'clean_20x_CD206_Smooth_nucleus_dataset.csv')
nucleus_dataset_tcps = pd.read_csv(preprocessed_data_path + 'clean_20x_CD206_TCPS_nucleus_dataset.csv')

# %% [markdown]
# # 20x CD206 P4G4 nucleus data

# %% [markdown]
# ## Train XGBClassifier

# %%
pipe_p4g4, test_data_p4g4 = macrophages_analysis.make_nucleus_classifier(nucleus_dataset_p4g4, confusion_matrix=True)
# Out:
# Mean accuracy of XGBClassifier (10-fold cross-validation) 0.9614646464646466
# Mean f1-macro of XGBClassifier (10-fold cross-validation) 0.9665765166095529
# Mean f1_weighted of XGBClassifier (10-fold cross-validation) 0.9615546246787281

# %% [markdown]
# ## One-vs-Rest multiclass ROC

# %%
macrophages_analysis.make_multiclass_roc(pipe_p4g4, test_data_p4g4)
# Out:
# AUC score for M1 1.0
# AUC score for M2 0.9977635715340634
# AUC score for NT 0.9977770787459369
# Average AUC 0.9985135500933334

# %% [markdown]
# ## Get the most important features

# %%
important_features_smooth = macrophages_analysis.get_best_features(pipe_p4g4, nucleus_dataset_p4g4.drop('CellType', axis=1), 10)
important_features_smooth.plot(x='Feature', y='Importance', kind='barh', figsize=(5, 5))
# Out:
# <AxesSubplot:ylabel='Feature'>

# %% [markdown]
# # 20x CD206 Smooth nucleus data

# %% [markdown]
# ## Train XGBClassifier

# %%
pipe_smooth, test_data_smooth = macrophages_analysis.make_nucleus_classifier(nucleus_dataset_smooth, confusion_matrix=True)
# Out:
# Mean accuracy of XGBClassifier (10-fold cross-validation) 0.8910344827586207
# Mean f1-macro of XGBClassifier (10-fold cross-validation) 0.9036760090929132
# Mean f1_weighted of XGBClassifier (10-fold cross-validation) 0.89130318096338

# %% [markdown]
# ## One-vs-Rest multiclass ROC

# %%
macrophages_analysis.make_multiclass_roc(pipe_smooth, test_data_smooth)
# Out:
# AUC score for M1 1.0
# AUC score for M2 0.9898484216381589
# AUC score for NT 0.9886440944057775
# Average AUC 0.9928308386813122

# %% [markdown]
# ## Get the most important features

# %%
important_features_smooth = macrophages_analysis.get_best_features(pipe_smooth, nucleus_dataset_smooth.drop('CellType', axis=1), 10)
important_features_smooth.plot(x='Feature', y='Importance', kind='barh', figsize=(5, 5))
# Out:
# <AxesSubplot:ylabel='Feature'>

# %% [markdown]
# # 20x CD206 TCPS nucleus data

# %% [markdown]
# ## Train XGBClassifier

# %%
pipe_tcps, test_data_tcps = macrophages_analysis.make_nucleus_classifier(nucleus_dataset_tcps, confusion_matrix=True)
# Out:
# Mean accuracy of XGBClassifier (10-fold cross-validation) 0.9173796791443849
# Mean f1-macro of XGBClassifier (10-fold cross-validation) 0.9193303444723977
# Mean f1_weighted of XGBClassifier (10-fold cross-validation) 0.9178811017021031

# %% [markdown]
# ## One-vs-Rest multiclass ROC

# %%
macrophages_analysis.make_multiclass_roc(pipe_tcps, test_data_tcps)
# Out:
# AUC score for M1 0.9997932282243474
# AUC score for M2 0.9872916441660368
# AUC score for NT 0.9896367199276456
# Average AUC 0.9922405307726766

# %% [markdown]
# ## Get the most important features

# %%
important_features_tcps = macrophages_analysis.get_best_features(pipe_tcps, nucleus_dataset_tcps.drop('CellType', axis=1), 10)
important_features_tcps.plot(x='Feature', y='Importance', kind='barh', figsize=(5, 5))
# Out:
# <AxesSubplot:ylabel='Feature'>
