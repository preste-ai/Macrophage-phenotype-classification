# %%
import pandas as pd
import sys
sys.path.append("../")
import macrophages_analysis

# %% [markdown]
# ## Data import

# %%
preprocessed_data_path = '../../20x_datasets/Preprocessed_data/'

nucleus_dataset_p4g4 = pd.read_csv(preprocessed_data_path + 'clean_20x_CD86_P4G4_nucleus_dataset.csv')
nucleus_dataset_smooth = pd.read_csv(preprocessed_data_path + 'clean_20x_CD86_Smooth_nucleus_dataset.csv')
nucleus_dataset_tcps = pd.read_csv(preprocessed_data_path + 'clean_20x_CD86_TCPS_nucleus_dataset.csv')

# %% [markdown]
# # 20x CD86 P4G4 nucleus data

# %% [markdown]
# ## Train XGBClassifier

# %%
pipe_p4g4, test_data_p4g4 = macrophages_analysis.make_nucleus_classifier(nucleus_dataset_p4g4, confusion_matrix=True)
# Out:
# Mean accuracy of XGBClassifier (10-fold cross-validation) 0.8504313725490198
# Mean f1-macro of XGBClassifier (10-fold cross-validation) 0.8456639096716693
# Mean f1_weighted of XGBClassifier (10-fold cross-validation) 0.8477335549531466

# %% [markdown]
# ## One-vs-Rest multiclass ROC

# %%
macrophages_analysis.make_multiclass_roc(pipe_p4g4, test_data_p4g4)
# Out:
# AUC score for M1 0.9988179669030732
# AUC score for M2 0.938375350140056
# AUC score for NT 0.9553521509241067
# Average AUC 0.9641818226557453

# %% [markdown]
# ## Get the most important features

# %%
important_features_smooth = macrophages_analysis.get_best_features(pipe_p4g4, nucleus_dataset_p4g4.drop('CellType', axis=1), 10)
important_features_smooth.plot(x='Feature', y='Importance', kind='barh', figsize=(5, 5))
# Out:
# <AxesSubplot:ylabel='Feature'>

# %% [markdown]
# # 20x CD86 Smooth nucleus data

# %% [markdown]
# ## Train XGBClassifier

# %%
pipe_smooth, test_data_smooth = macrophages_analysis.make_nucleus_classifier(nucleus_dataset_smooth, confusion_matrix=True)
# Out:
# Mean accuracy of XGBClassifier (10-fold cross-validation) 0.889616935483871
# Mean f1-macro of XGBClassifier (10-fold cross-validation) 0.8854076271664104
# Mean f1_weighted of XGBClassifier (10-fold cross-validation) 0.8895851611026337

# %% [markdown]
# ## One-vs-Rest multiclass ROC

# %%
macrophages_analysis.make_multiclass_roc(pipe_smooth, test_data_smooth)
# Out:
# AUC score for M1 0.9888625080941076
# AUC score for M2 0.9950550395596836
# AUC score for NT 0.99680495715738
# Average AUC 0.9935741682703904

# %% [markdown]
# ## Get the most important features

# %%
important_features_smooth = macrophages_analysis.get_best_features(pipe_smooth, nucleus_dataset_smooth.drop('CellType', axis=1), 10)
important_features_smooth.plot(x='Feature', y='Importance', kind='barh', figsize=(5, 5))
# Out:
# <AxesSubplot:ylabel='Feature'>

# %% [markdown]
# # 20x CD86 TCPS nucleus data

# %% [markdown]
# ## Train XGBClassifier

# %%
pipe_tcps, test_data_tcps = macrophages_analysis.make_nucleus_classifier(nucleus_dataset_tcps, confusion_matrix=True)
# Out:
# Mean accuracy of XGBClassifier (10-fold cross-validation) 0.9380952380952381
# Mean f1-macro of XGBClassifier (10-fold cross-validation) 0.9245922859519371
# Mean f1_weighted of XGBClassifier (10-fold cross-validation) 0.9372639638475574

# %% [markdown]
# ## One-vs-Rest multiclass ROC

# %%
macrophages_analysis.make_multiclass_roc(pipe_tcps, test_data_tcps)
# Out:
# AUC score for M1 0.9961388581030353
# AUC score for M2 0.9932426303854875
# AUC score for NT 0.9987100588535648
# Average AUC 0.9960305157806958

# %% [markdown]
# ## Get the most important features

# %%
important_features_tcps = macrophages_analysis.get_best_features(pipe_tcps, nucleus_dataset_tcps.drop('CellType', axis=1), 10)
important_features_tcps.plot(x='Feature', y='Importance', kind='barh', figsize=(5, 5))
# Out:
# <AxesSubplot:ylabel='Feature'>
