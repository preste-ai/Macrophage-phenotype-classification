# %%
import pandas as pd
import sys
sys.path.append("../")
import macrophages_analysis

# %% [markdown]
# ## Data import

# %%
preprocessed_data_path = '../../20x_datasets/Preprocessed_data/'

nucleus_dataset_p4g4 = pd.read_csv(preprocessed_data_path + 'clean_20x_CD86_P4G4_nucleus_dataset_no_shape_data.csv')
nucleus_dataset_smooth = pd.read_csv(preprocessed_data_path + 'clean_20x_CD86_Smooth_nucleus_dataset_no_shape_data.csv')
nucleus_dataset_tcps = pd.read_csv(preprocessed_data_path + 'clean_20x_CD86_TCPS_nucleus_dataset_no_shape_data.csv')

# %% [markdown]
# # 20x CD86 P4G4 nucleus data

# %% [markdown]
# ## Train XGBClassifier

# %%
nucleus_classifier_p4g4, test_data_p4g4 = macrophages_analysis.make_nucleus_classifier(nucleus_dataset_p4g4, confusion_matrix=True)
# Out:
# Mean accuracy of XGBClassifier (10-fold cross-validation) 0.8419243986254296
# Mean f1-macro of XGBClassifier (10-fold cross-validation) 0.8530646280834618

# %% [markdown]
# ## One-vs-Rest multiclass ROC

# %%
macrophages_analysis.make_multiclass_roc(nucleus_classifier_p4g4, test_data_p4g4)
# Out:
# AUC score for M1 0.9983389450056116
# AUC score for M2 0.9495488605125477
# AUC score for NT 0.960154894876979
# Average AUC 0.9693475667983794

# %% [markdown]
# ## Get the most important features

# %%
important_features_smooth = macrophages_analysis.get_best_features(nucleus_classifier_p4g4, nucleus_dataset_p4g4.drop('CellType', axis=1), 10)
important_features_smooth.plot(x='Feature', y='Importance', kind='barh', figsize=(5, 5))
# Out:
# <AxesSubplot:ylabel='Feature'>

# %% [markdown]
# # 20x CD86 Smooth nucleus data

# %% [markdown]
# ## Train XGBClassifier

# %%
nucleus_classifier_smooth, test_data_smooth = macrophages_analysis.make_nucleus_classifier(nucleus_dataset_smooth, confusion_matrix=True)
# Out:
# Mean accuracy of XGBClassifier (10-fold cross-validation) 0.8927740715180329
# Mean f1-macro of XGBClassifier (10-fold cross-validation) 0.8911141485794535

# %% [markdown]
# ## One-vs-Rest multiclass ROC

# %%
macrophages_analysis.make_multiclass_roc(nucleus_classifier_smooth, test_data_smooth)
# Out:
# AUC score for M1 0.9870453601238811
# AUC score for M2 0.9935482698458855
# AUC score for NT 0.9972016873407676
# Average AUC 0.9925984391035114

# %% [markdown]
# ## Get the most important features

# %%
important_features_smooth = macrophages_analysis.get_best_features(nucleus_classifier_smooth, nucleus_dataset_smooth.drop('CellType', axis=1), 10)
important_features_smooth.plot(x='Feature', y='Importance', kind='barh', figsize=(5, 5))
# Out:
# <AxesSubplot:ylabel='Feature'>

# %% [markdown]
# # 20x CD86 TCPS nucleus data

# %% [markdown]
# ## Train XGBClassifier

# %%
nucleus_classifier_tcps, test_data_tcps = macrophages_analysis.make_nucleus_classifier(nucleus_dataset_tcps, confusion_matrix=True)
# Out:
# Mean accuracy of XGBClassifier (10-fold cross-validation) 0.9433465085638999
# Mean f1-macro of XGBClassifier (10-fold cross-validation) 0.9373766873369117

# %% [markdown]
# ## One-vs-Rest multiclass ROC

# %%
macrophages_analysis.make_multiclass_roc(nucleus_classifier_tcps, test_data_tcps)
# Out:
# AUC score for M1 0.9965721787329217
# AUC score for M2 0.9957928664128125
# AUC score for NT 0.9992312666139809
# Average AUC 0.9971987705865718

# %% [markdown]
# ## Get the most important features

# %%
important_features_tcps = macrophages_analysis.get_best_features(nucleus_classifier_tcps, nucleus_dataset_tcps.drop('CellType', axis=1), 10)
important_features_tcps.plot(x='Feature', y='Importance', kind='barh', figsize=(5, 5))
# Out:
# <AxesSubplot:ylabel='Feature'>
