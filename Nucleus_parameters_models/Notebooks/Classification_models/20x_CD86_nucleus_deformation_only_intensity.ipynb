# %%
import pandas as pd
import sys
sys.path.append("../")
import macrophages_analysis

# %% [markdown]
# ## Data import

# %%
preprocessed_data_path = '../../20x_datasets/Preprocessed_data/'

nucleus_dataset_p4g4 = pd.read_csv(preprocessed_data_path + 'clean_20x_CD86_P4G4_nucleus_dataset_texture.csv')
nucleus_dataset_smooth = pd.read_csv(preprocessed_data_path + 'clean_20x_CD86_Smooth_nucleus_dataset_texture.csv')
nucleus_dataset_tcps = pd.read_csv(preprocessed_data_path + 'clean_20x_CD86_TCPS_nucleus_dataset_texture.csv')

# %% [markdown]
# # 20x CD86 P4G4 nucleus data

# %% [markdown]
# ## Train XGBClassifier

# %%
pipe_p4g4, test_data_p4g4 = macrophages_analysis.make_nucleus_classifier(nucleus_dataset_p4g4, confusion_matrix=True)
# Out:
# Mean accuracy of XGBClassifier (10-fold cross-validation) 0.7283752191700759
# Mean f1-macro of XGBClassifier (10-fold cross-validation) 0.719410794472821

# %% [markdown]
# ## One-vs-Rest multiclass ROC

# %%
macrophages_analysis.make_multiclass_roc(pipe_p4g4, test_data_p4g4)
# Out:
# AUC score for M1 0.954949494949495
# AUC score for M2 0.8540876895450917
# AUC score for NT 0.9112558417022969
# Average AUC 0.9067643420656278

# %% [markdown]
# ## Get the most important features

# %%
important_features_smooth = macrophages_analysis.get_best_features(pipe_p4g4, nucleus_dataset_p4g4.drop('CellType', axis=1), 10)
important_features_smooth.plot(x='Feature', y='Importance', kind='barh', figsize=(5, 5))
# Out:
# <AxesSubplot:ylabel='Feature'>

# %% [markdown]
# # 20x CD86 Smooth nucleus data

# %% [markdown]
# ## Train XGBClassifier

# %%
pipe_smooth, test_data_smooth = macrophages_analysis.make_nucleus_classifier(nucleus_dataset_smooth, confusion_matrix=True)
# Out:
# Mean accuracy of XGBClassifier (10-fold cross-validation) 0.8212121212121211
# Mean f1-macro of XGBClassifier (10-fold cross-validation) 0.8165448372711672

# %% [markdown]
# ## One-vs-Rest multiclass ROC

# %%
macrophages_analysis.make_multiclass_roc(pipe_smooth, test_data_smooth)
# Out:
# AUC score for M1 0.9369369369369368
# AUC score for M2 0.9814354924072792
# AUC score for NT 0.9760119940029985
# Average AUC 0.9647948077824049

# %% [markdown]
# ## Get the most important features

# %%
important_features_smooth = macrophages_analysis.get_best_features(pipe_smooth, nucleus_dataset_smooth.drop('CellType', axis=1), 10)
important_features_smooth.plot(x='Feature', y='Importance', kind='barh', figsize=(5, 5))
# Out:
# <AxesSubplot:ylabel='Feature'>

# %% [markdown]
# # 20x CD86 TCPS nucleus data

# %% [markdown]
# ## Train XGBClassifier

# %%
pipe_tcps, test_data_tcps = macrophages_analysis.make_nucleus_classifier(nucleus_dataset_tcps, confusion_matrix=True)
# Out:
# Mean accuracy of XGBClassifier (10-fold cross-validation) 0.7492941176470589
# Mean f1-macro of XGBClassifier (10-fold cross-validation) 0.6770671232522173

# %% [markdown]
# ## One-vs-Rest multiclass ROC

# %%
macrophages_analysis.make_multiclass_roc(pipe_tcps, test_data_tcps)
# Out:
# AUC score for M1 0.8542506789564646
# AUC score for M2 0.8799095109742011
# AUC score for NT 0.9726948120142827
# Average AUC 0.9022850006483161

# %% [markdown]
# ## Get the most important features

# %%
important_features_tcps = macrophages_analysis.get_best_features(pipe_tcps, nucleus_dataset_tcps.drop('CellType', axis=1), 10)
important_features_tcps.plot(x='Feature', y='Importance', kind='barh', figsize=(5, 5))
# Out:
# <AxesSubplot:ylabel='Feature'>
