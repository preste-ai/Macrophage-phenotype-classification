# %%
import pandas as pd
from scipy.stats import ttest_ind

dataset = pd.read_csv('green_P4G4_Cell.csv')

# %%
results = []

for image_m1 in range(1,4):
    for image_m2 in range(4, 7):
        current_images = 'M1_' + str(image_m1) + '_M2_' +str(image_m2)
        # divide the data into two datasets - for M1 and M2 cells data
        dataset_m1 = dataset[dataset['ImageNumber'] == image_m1]
        dataset_m2 = dataset[dataset['ImageNumber'] == image_m2]
        
        t_statistic, p_value = ttest_ind(dataset_m1['Intensity_MeanIntensity_Green'], dataset_m2['Intensity_MeanIntensity_Green'])
        mean_diff = dataset_m2['Intensity_MeanIntensity_Green'].mean() - dataset_m1['Intensity_MeanIntensity_Green'].mean()
        results.append((current_images, mean_diff, t_statistic, p_value))
        
t_test_results = pd.DataFrame(results, columns=['Image', 'mean_diff (M2 - M1)', 't_statistic', 'p_value'])
t_test_results[t_test_results['p_value'] < 0.05].sort_values(by='p_value')
# Out:
#        Image  mean_diff (M2 - M1)  t_statistic        p_value
# 2  M1_1_M2_6             0.151240   -69.713201   0.000000e+00
# 5  M1_2_M2_6             0.177865   -90.335132   0.000000e+00
# 4  M1_2_M2_5             0.147735   -60.137684  3.728403e-283
# 1  M1_1_M2_5             0.121111   -49.008570  7.072198e-246
# 3  M1_2_M2_4             0.114776   -47.910471  4.244201e-232
# 8  M1_3_M2_6             0.166178   -45.738392  4.737173e-198
# 0  M1_1_M2_4             0.088151   -36.759284  1.285878e-178
# 7  M1_3_M2_5             0.136048   -34.472433  2.819411e-148
# 6  M1_3_M2_4             0.103089   -26.998737  7.500887e-110

# %%
# change image numbers assigned by cellprofiler to cell type names
dataset.loc[dataset['ImageNumber'].isin([1, 2, 3]), 'CellType'] = 'M1'
dataset.loc[dataset['ImageNumber'].isin([4, 5, 6]), 'CellType'] = 'M2'

# divide the data into two datasets - for M1 and M2 cells data
dataset_m1 = dataset[dataset['CellType'] == 'M1']
dataset_m2 = dataset[dataset['CellType'] == 'M2']

# %%
t_test_results = pd.DataFrame(columns=['Measurement', 'mean_diff (M2 - M1)', 't_statistic', 'p_value'])

for column in range(2, 17):
    column_name = dataset_m1.columns[column] 
    t_statistic, p_value = ttest_ind(dataset_m1[column_name], dataset_m2[column_name])
    mean_diff = dataset_m2[column_name].mean() - dataset_m1[column_name].mean()
    t_test_results.loc[column] = [column_name, mean_diff, t_statistic, p_value]

# %%
# statistically significant difference
t_test_results[t_test_results['p_value'] < 0.05]
# Out:
#                                 Measurement  mean_diff (M2 - M1)  t_statistic  \
# 2   Intensity_IntegratedIntensityEdge_Green            14.824328   -41.165034
# 3       Intensity_IntegratedIntensity_Green           167.459174   -28.995094
# 4    Intensity_LowerQuartileIntensity_Green             0.104114   -85.877384
# 5              Intensity_MADIntensity_Green             0.023704   -31.699931
# 7          Intensity_MaxIntensityEdge_Green             0.167436   -54.435852
# 8              Intensity_MaxIntensity_Green             0.347061   -52.573131
# 9         Intensity_MeanIntensityEdge_Green             0.093279   -91.529965
# 10            Intensity_MeanIntensity_Green             0.130352   -70.575845
# 11          Intensity_MedianIntensity_Green             0.125458   -61.866928
# 12         Intensity_MinIntensityEdge_Green             0.039128   -49.685598
# 13             Intensity_MinIntensity_Green             0.039190   -50.861299
# 14         Intensity_StdIntensityEdge_Green             0.025909   -36.055229
# 15             Intensity_StdIntensity_Green             0.041580   -28.671606
# 16   Intensity_UpperQuartileIntensity_Green             0.150068   -51.475074
#
#           p_value
# 2   8.474703e-275
# 3   1.058391e-156
# 4    0.000000e+00
# 5   8.272420e-182
# 7    0.000000e+00
# 8    0.000000e+00
# 9    0.000000e+00
# 10   0.000000e+00
# 11   0.000000e+00
# 12   0.000000e+00
# 13   0.000000e+00
# 14  7.616216e-224
# 15  9.195424e-154
# 16   0.000000e+00

# %%
# not statistically significant difference
t_test_results[t_test_results['p_value'] >= 0.05]
# Out:
#                         Measurement  mean_diff (M2 - M1)  t_statistic  \
# 6  Intensity_MassDisplacement_Green             0.038641    -1.089631
#
#     p_value
# 6  0.275996

# %%
dataset_m1.describe()
# Out:
#        ImageNumber  ObjectNumber  Intensity_IntegratedIntensityEdge_Green  \
# count   813.000000    813.000000                               813.000000
# mean      1.782288    145.678967                                 9.762592
# std       0.792875     93.420465                                 4.504722
# min       1.000000      1.000000                                 1.831074
# 25%       1.000000     68.000000                                 6.273672
# 50%       2.000000    136.000000                                 8.801182
# 75%       2.000000    212.000000                                12.275167
# max       3.000000    363.000000                                29.153454
#
#        Intensity_IntegratedIntensity_Green  \
# count                           813.000000
# mean                             89.308688
# std                              66.332889
# min                              18.928755
# 25%                              41.873695
# 50%                              70.949899
# 75%                             119.182144
# max                             668.848406
#
#        Intensity_LowerQuartileIntensity_Green  Intensity_MADIntensity_Green  \
# count                              813.000000                    813.000000
# mean                                 0.061187                      0.017736
# std                                  0.011695                      0.015500
# min                                  0.022727                      0.000000
# 25%                                  0.051347                      0.014310
# 50%                                  0.057241                      0.017116
# 75%                                  0.071551                      0.019921
# max                                  0.142606                      0.421557
#
#        Intensity_MassDisplacement_Green  Intensity_MaxIntensityEdge_Green  \
# count                        813.000000                        813.000000
# mean                           0.888815                          0.113407
# std                            0.754006                          0.067020
# min                            0.019052                          0.037037
# 25%                            0.420919                          0.088667
# 50%                            0.679403                          0.105782
# 75%                            1.154394                          0.125704
# max                            5.922801                          1.000000
#
#        Intensity_MaxIntensity_Green  Intensity_MeanIntensityEdge_Green  ...  \
# count                    813.000000                         813.000000  ...
# mean                       0.245672                           0.060668  ...
# std                        0.147053                           0.011453  ...
# min                        0.097083                           0.025219  ...
# 25%                        0.160218                           0.051736  ...
# 50%                        0.197255                           0.055998  ...
# 75%                        0.274699                           0.071151  ...
# max                        1.000000                           0.159394  ...
#
#        Location_CenterMassIntensity_X_Green  \
# count                            813.000000
# mean                             514.753170
# std                              273.955238
# min                               11.566036
# 25%                              282.293556
# 50%                              510.271129
# 75%                              750.566248
# max                             1005.414869
#
#        Location_CenterMassIntensity_Y_Green  \
# count                            813.000000
# mean                             503.919285
# std                              275.485144
# min                               18.356162
# 25%                              280.348855
# 50%                              511.679798
# 75%                              723.024203
# max                             1002.351310
#
#        Location_CenterMassIntensity_Z_Green  Location_Center_X  \
# count                                 813.0         813.000000
# mean                                    0.0         514.766903
# std                                     0.0         273.916445
# min                                     0.0          12.357576
# 25%                                     0.0         282.278287
# 50%                                     0.0         510.656170
# 75%                                     0.0         751.144638
# max                                     0.0        1005.762887
#
#        Location_Center_Y  Location_Center_Z  Location_MaxIntensity_X_Green  \
# count         813.000000              813.0                     813.000000
# mean          503.890813                0.0                     515.097171
# std           275.540341                0.0                     274.567599
# min            18.825163                0.0                       8.000000
# 25%           280.043677                0.0                     283.000000
# 50%           512.107039                0.0                     509.000000
# 75%           722.533151                0.0                     752.000000
# max          1001.937722                0.0                    1006.000000
#
#        Location_MaxIntensity_Y_Green  Location_MaxIntensity_Z_Green  \
# count                     813.000000                          813.0
# mean                      504.121771                            0.0
# std                       274.877592                            0.0
# min                         6.000000                            0.0
# 25%                       281.000000                            0.0
# 50%                       513.000000                            0.0
# 75%                       720.000000                            0.0
# max                      1004.000000                            0.0
#
#        Number_Object_Number
# count            813.000000
# mean             145.678967
# std               93.420465
# min                1.000000
# 25%               68.000000
# 50%              136.000000
# 75%              212.000000
# max              363.000000
#
# [8 rows x 27 columns]

# %%
dataset_m2.describe()
# Out:
#        ImageNumber  ObjectNumber  Intensity_IntegratedIntensityEdge_Green  \
# count  1377.000000   1377.000000                              1377.000000
# mean      4.940450    231.220770                                24.586920
# std       0.814618    134.642768                                 9.666439
# min       4.000000      1.000000                                 2.245221
# 25%       4.000000    115.000000                                17.308507
# 50%       5.000000    230.000000                                23.057009
# 75%       6.000000    345.000000                                30.168240
# max       6.000000    500.000000                                84.056870
#
#        Intensity_IntegratedIntensity_Green  \
# count                          1377.000000
# mean                            256.767863
# std                             156.577425
# min                              21.198899
# 25%                             141.518437
# 50%                             220.512934
# 75%                             333.912667
# max                            1119.167035
#
#        Intensity_LowerQuartileIntensity_Green  Intensity_MADIntensity_Green  \
# count                             1377.000000                   1377.000000
# mean                                 0.165302                      0.041439
# std                                  0.033377                      0.017684
# min                                  0.028620                      0.005894
# 25%                                  0.143102                      0.031426
# 50%                                  0.165829                      0.040125
# 75%                                  0.188838                      0.048542
# max                                  0.277505                      0.396621
#
#        Intensity_MassDisplacement_Green  Intensity_MaxIntensityEdge_Green  \
# count                       1377.000000                       1377.000000
# mean                           0.927456                          0.280843
# std                            0.828705                          0.070990
# min                            0.012251                          0.039842
# 25%                            0.405380                          0.237380
# 50%                            0.682516                          0.274699
# 75%                            1.169712                          0.311736
# max                            7.172146                          1.000000
#
#        Intensity_MaxIntensity_Green  Intensity_MeanIntensityEdge_Green  ...  \
# count                   1377.000000                        1377.000000  ...
# mean                       0.592733                           0.153948  ...
# std                        0.150541                           0.027691  ...
# min                        0.237380                           0.028065  ...
# 25%                        0.460732                           0.136356  ...
# 50%                        0.649570                           0.153333  ...
# 75%                        0.726732                           0.172176  ...
# max                        1.000000                           0.240676  ...
#
#        Location_CenterMassIntensity_X_Green  \
# count                           1377.000000
# mean                             503.483534
# std                              278.741656
# min                               20.501178
# 25%                              259.082844
# 50%                              499.325600
# 75%                              740.815559
# max                              999.489687
#
#        Location_CenterMassIntensity_Y_Green  \
# count                           1377.000000
# mean                             517.652301
# std                              277.855959
# min                               20.062711
# 25%                              293.989580
# 50%                              516.498240
# 75%                              752.047285
# max                              999.298743
#
#        Location_CenterMassIntensity_Z_Green  Location_Center_X  \
# count                                1377.0        1377.000000
# mean                                    0.0         503.514190
# std                                     0.0         278.681289
# min                                     0.0          20.318095
# 25%                                     0.0         258.832831
# 50%                                     0.0         500.084098
# 75%                                     0.0         742.237393
# max                                     0.0         999.623274
#
#        Location_Center_Y  Location_Center_Z  Location_MaxIntensity_X_Green  \
# count        1377.000000             1377.0                    1377.000000
# mean          517.605882                0.0                     503.025418
# std           277.799827                0.0                     279.194307
# min            19.994429                0.0                       8.000000
# 25%           293.321168                0.0                     256.000000
# 50%           516.279481                0.0                     504.000000
# 75%           752.003998                0.0                     744.000000
# max          1000.054935                0.0                    1015.000000
#
#        Location_MaxIntensity_Y_Green  Location_MaxIntensity_Z_Green  \
# count                    1377.000000                         1377.0
# mean                      517.771968                            0.0
# std                       278.200617                            0.0
# min                        16.000000                            0.0
# 25%                       288.000000                            0.0
# 50%                       518.000000                            0.0
# 75%                       754.000000                            0.0
# max                      1008.000000                            0.0
#
#        Number_Object_Number
# count           1377.000000
# mean             231.220770
# std              134.642768
# min                1.000000
# 25%              115.000000
# 50%              230.000000
# 75%              345.000000
# max              500.000000
#
# [8 rows x 27 columns]
