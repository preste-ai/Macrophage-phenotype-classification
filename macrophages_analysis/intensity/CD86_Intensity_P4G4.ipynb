# %%
import pandas as pd
from scipy.stats import ttest_ind

dataset = pd.read_csv('CD86_green_P4G4_Cell.csv')

# %%
results = []

for image_m1 in range(1,4):
    for image_m2 in range(4, 7):
        current_images = 'M1_' + str(image_m1) + '_M2_' +str(image_m2)
        # divide the data into two datasets - for M1 and M2 cells data
        dataset_m1 = dataset[dataset['ImageNumber'] == image_m1]
        dataset_m2 = dataset[dataset['ImageNumber'] == image_m2]
        
        t_statistic, p_value = ttest_ind(dataset_m1['Intensity_MeanIntensity_Green'], dataset_m2['Intensity_MeanIntensity_Green'])
        mean_diff = dataset_m2['Intensity_MeanIntensity_Green'].mean() - dataset_m1['Intensity_MeanIntensity_Green'].mean()
        results.append((current_images, mean_diff, t_statistic, p_value))
        
t_test_results = pd.DataFrame(results, columns=['Image', 'mean_diff (M2 - M1)', 't_statistic', 'p_value'])
t_test_results[t_test_results['p_value'] < 0.05].sort_values(by='p_value')
# Out:
#        Image  mean_diff (M2 - M1)  t_statistic       p_value
# 8  M1_3_M2_6            -0.070939    22.639768  3.016929e-86
# 7  M1_3_M2_5            -0.071739    22.189424  3.621362e-81
# 5  M1_2_M2_6            -0.069036    18.937374  5.498238e-65
# 6  M1_3_M2_4            -0.065167    18.259549  2.431955e-60
# 4  M1_2_M2_5            -0.069836    18.299075  4.805701e-60
# 3  M1_2_M2_4            -0.063264    15.353828  2.229617e-45
# 0  M1_1_M2_4             0.006890    -2.450110  1.452541e-02

# %%
# change image numbers assigned by cellprofiler to cell type names
dataset.loc[dataset['ImageNumber'].isin([1, 2, 3]), 'CellType'] = 'M1'
dataset.loc[dataset['ImageNumber'].isin([4, 5, 6]), 'CellType'] = 'M2'

# divide the data into two datasets - for M1 and M2 cells data
dataset_m1 = dataset[dataset['CellType'] == 'M1']
dataset_m2 = dataset[dataset['CellType'] == 'M2']

# %%
t_test_results = pd.DataFrame(columns=['Measurement', 'mean_diff (M1 - M2)', 't_statistic', 'p_value'])

for column in range(2, 17):
    column_name = dataset_m1.columns[column] 
    t_statistic, p_value = ttest_ind(dataset_m1[column_name], dataset_m2[column_name])
    mean_diff = dataset_m1[column_name].mean() - dataset_m2[column_name].mean()
    t_test_results.loc[column] = [column_name, mean_diff, t_statistic, p_value]

# %%
# statistically significant difference
t_test_results[t_test_results['p_value'] < 0.05]
# Out:
#                                 Measurement  mean_diff (M1 - M2)  t_statistic  \
# 2   Intensity_IntegratedIntensityEdge_Green             4.454035     6.490794
# 3       Intensity_IntegratedIntensity_Green            58.256181     4.883510
# 4    Intensity_LowerQuartileIntensity_Green             0.026859    18.927902
# 5              Intensity_MADIntensity_Green             0.014330    17.663132
# 6          Intensity_MassDisplacement_Green            -0.154167    -3.566396
# 7          Intensity_MaxIntensityEdge_Green             0.035953     9.868816
# 8              Intensity_MaxIntensity_Green            -0.028451    -5.226827
# 9         Intensity_MeanIntensityEdge_Green             0.022094    18.766996
# 10            Intensity_MeanIntensity_Green             0.040543    19.378625
# 11          Intensity_MedianIntensity_Green             0.041303    18.582764
# 12         Intensity_MinIntensityEdge_Green             0.010375    10.292253
# 13             Intensity_MinIntensity_Green             0.008473     8.684811
# 14         Intensity_StdIntensityEdge_Green             0.007181     9.005533
# 15             Intensity_StdIntensity_Green             0.012383     9.757576
# 16   Intensity_UpperQuartileIntensity_Green             0.057663    18.786101
#
#          p_value
# 2   1.068619e-10
# 3   1.123052e-06
# 4   9.509653e-74
# 5   4.338241e-65
# 6   3.702501e-04
# 7   1.791778e-22
# 8   1.900234e-07
# 9   1.268475e-72
# 10  6.182344e-77
# 11  2.416768e-71
# 12  2.953522e-24
# 13  7.620647e-18
# 14  4.793240e-19
# 15  5.136069e-22
# 16  9.333583e-73

# %%
# not statistically significant difference
t_test_results[t_test_results['p_value'] >= 0.05]
# Out:
# Empty DataFrame
# Columns: [Measurement, mean_diff (M1 - M2), t_statistic, p_value]
# Index: []

# %%
dataset_m1.describe()
# Out:
#        ImageNumber  ObjectNumber  Intensity_IntegratedIntensityEdge_Green  \
# count   729.000000    729.000000                               729.000000
# mean      1.924554    124.026063                                35.985000
# std       0.839324     73.744813                                14.913821
# min       1.000000      1.000000                                11.272454
# 25%       1.000000     61.000000                                24.360889
# 50%       2.000000    122.000000                                33.839567
# 75%       3.000000    183.000000                                44.998649
# max       3.000000    286.000000                               101.738118
#
#        Intensity_IntegratedIntensity_Green  \
# count                           729.000000
# mean                            364.681869
# std                             302.665478
# min                              55.138313
# 25%                             157.727343
# 50%                             279.274601
# 75%                             460.228853
# max                            2427.920142
#
#        Intensity_LowerQuartileIntensity_Green  Intensity_MADIntensity_Green  \
# count                              729.000000                    729.000000
# mean                                 0.194202                      0.050463
# std                                  0.039516                      0.028173
# min                                  0.111393                      0.000000
# 25%                                  0.165829                      0.037037
# 50%                                  0.194449                      0.042931
# 75%                                  0.214653                      0.054435
# max                                  0.626560                      0.389871
#
#        Intensity_MassDisplacement_Green  Intensity_MaxIntensityEdge_Green  \
# count                        729.000000                        729.000000
# mean                           0.769731                          0.357678
# std                            0.759793                          0.098082
# min                            0.010228                          0.194449
# 25%                            0.308536                          0.300514
# 50%                            0.578049                          0.337551
# 75%                            0.921917                          0.380482
# max                            8.027018                          1.000000
#
#        Intensity_MaxIntensity_Green  Intensity_MeanIntensityEdge_Green  ...  \
# count                    729.000000                         729.000000  ...
# mean                       0.610762                           0.194059  ...
# std                        0.127751                           0.030391  ...
# min                        0.268805                           0.119624  ...
# 25%                        0.503662                           0.166894  ...
# 50%                        0.649570                           0.201300  ...
# 75%                        0.726732                           0.208145  ...
# max                        1.000000                           0.491102  ...
#
#        Location_CenterMassIntensity_X_Green  \
# count                            729.000000
# mean                             496.600483
# std                              271.847005
# min                               21.986723
# 25%                              272.901422
# 50%                              468.877585
# 75%                              728.658827
# max                              997.670706
#
#        Location_CenterMassIntensity_Y_Green  \
# count                            729.000000
# mean                             532.575842
# std                              277.830708
# min                               21.774432
# 25%                              292.911849
# 50%                              550.294197
# 75%                              775.674846
# max                             1003.166710
#
#        Location_CenterMassIntensity_Z_Green  Location_Center_X  \
# count                                 729.0         729.000000
# mean                                    0.0         496.545118
# std                                     0.0         271.830441
# min                                     0.0          22.228070
# 25%                                     0.0         273.376231
# 50%                                     0.0         469.134146
# 75%                                     0.0         728.737218
# max                                     0.0         997.039106
#
#        Location_Center_Y  Location_Center_Z  Location_MaxIntensity_X_Green  \
# count         729.000000              729.0                     729.000000
# mean          532.556312                0.0                     497.466392
# std           277.835638                0.0                     272.085736
# min            21.541763                0.0                      22.000000
# 25%           293.505428                0.0                     275.000000
# 50%           549.917213                0.0                     469.000000
# 75%           775.531172                0.0                     731.000000
# max          1003.390476                0.0                    1006.000000
#
#        Location_MaxIntensity_Y_Green  Location_MaxIntensity_Z_Green  \
# count                     729.000000                          729.0
# mean                      532.646091                            0.0
# std                       277.905838                            0.0
# min                        20.000000                            0.0
# 25%                       293.000000                            0.0
# 50%                       556.000000                            0.0
# 75%                       773.000000                            0.0
# max                      1008.000000                            0.0
#
#        Number_Object_Number
# count            729.000000
# mean             124.026063
# std               73.744813
# min                1.000000
# 25%               61.000000
# 50%              122.000000
# 75%              183.000000
# max              286.000000
#
# [8 rows x 27 columns]

# %%
dataset_m2.describe()
# Out:
#        ImageNumber  ObjectNumber  Intensity_IntegratedIntensityEdge_Green  \
# count  1316.000000   1316.000000                              1316.000000
# mean      5.061550    221.725684                                31.530965
# std       0.830051    130.037351                                14.834490
# min       4.000000      1.000000                                 4.966964
# 25%       4.000000    110.000000                                20.415984
# 50%       5.000000    220.000000                                28.226295
# 75%       6.000000    329.250000                                39.056383
# max       6.000000    496.000000                               102.983755
#
#        Intensity_IntegratedIntensity_Green  \
# count                          1316.000000
# mean                            306.425689
# std                             230.224302
# min                              29.285900
# 25%                             144.860374
# 50%                             234.522311
# 75%                             397.855903
# max                            1608.175203
#
#        Intensity_LowerQuartileIntensity_Green  Intensity_MADIntensity_Green  \
# count                             1316.000000                   1316.000000
# mean                                 0.167343                      0.036133
# std                                  0.024558                      0.006351
# min                                  0.057241                      0.000000
# 25%                                  0.157412                      0.032829
# 50%                                  0.168634                      0.034514
# 75%                                  0.182944                      0.037320
# max                                  0.348685                      0.108871
#
#        Intensity_MassDisplacement_Green  Intensity_MaxIntensityEdge_Green  \
# count                       1316.000000                       1316.000000
# mean                           0.923899                          0.321725
# std                            1.020953                          0.065935
# min                            0.007088                          0.105782
# 25%                            0.361954                          0.283116
# 50%                            0.626297                          0.314824
# 75%                            1.062042                          0.351861
# max                            9.138926                          1.000000
#
#        Intensity_MaxIntensity_Green  Intensity_MeanIntensityEdge_Green  ...  \
# count                   1316.000000                        1316.000000  ...
# mean                       0.639213                           0.171965  ...
# std                        0.112069                           0.022335  ...
# min                        0.140014                           0.059843  ...
# 25%                        0.560903                           0.159524  ...
# 50%                        0.704005                           0.172990  ...
# 75%                        0.726732                           0.186681  ...
# max                        1.000000                           0.223431  ...
#
#        Location_CenterMassIntensity_X_Green  \
# count                           1316.000000
# mean                             502.626237
# std                              273.052805
# min                               13.082153
# 25%                              267.749118
# 50%                              509.493075
# 75%                              735.251790
# max                             1001.434238
#
#        Location_CenterMassIntensity_Y_Green  \
# count                           1316.000000
# mean                             517.931185
# std                              277.534056
# min                               19.379976
# 25%                              281.932125
# 50%                              517.135894
# 75%                              757.347834
# max                             1000.652208
#
#        Location_CenterMassIntensity_Z_Green  Location_Center_X  \
# count                                1316.0        1316.000000
# mean                                    0.0         502.621235
# std                                     0.0         273.087117
# min                                     0.0          13.285714
# 25%                                     0.0         268.395822
# 50%                                     0.0         509.736120
# 75%                                     0.0         735.193311
# max                                     0.0        1001.461066
#
#        Location_Center_Y  Location_Center_Z  Location_MaxIntensity_X_Green  \
# count        1316.000000             1316.0                    1316.000000
# mean          517.942088                0.0                     502.718845
# std           277.524191                0.0                     272.870197
# min            19.449821                0.0                       8.000000
# 25%           282.115482                0.0                     268.000000
# 50%           514.923406                0.0                     508.500000
# 75%           756.711667                0.0                     736.000000
# max          1000.819473                0.0                    1011.000000
#
#        Location_MaxIntensity_Y_Green  Location_MaxIntensity_Z_Green  \
# count                    1316.000000                         1316.0
# mean                      518.411854                            0.0
# std                       277.859642                            0.0
# min                        16.000000                            0.0
# 25%                       280.750000                            0.0
# 50%                       516.500000                            0.0
# 75%                       758.000000                            0.0
# max                      1012.000000                            0.0
#
#        Number_Object_Number
# count           1316.000000
# mean             221.725684
# std              130.037351
# min                1.000000
# 25%              110.000000
# 50%              220.000000
# 75%              329.250000
# max              496.000000
#
# [8 rows x 27 columns]
