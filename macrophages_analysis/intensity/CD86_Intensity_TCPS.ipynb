# %%
import pandas as pd
from scipy.stats import ttest_ind

dataset = pd.read_csv('CD86_green_TCPS_Cell.csv')

# %%
results = []

for image_m1 in range(1,4):
    for image_m2 in range(4, 7):
        current_images = 'M1_' + str(image_m1) + '_M2_' +str(image_m2)
        # divide the data into two datasets - for M1 and M2 cells data
        dataset_m1 = dataset[dataset['ImageNumber'] == image_m1]
        dataset_m2 = dataset[dataset['ImageNumber'] == image_m2]
        
        t_statistic, p_value = ttest_ind(dataset_m1['Intensity_MeanIntensity_Green'], dataset_m2['Intensity_MeanIntensity_Green'])
        mean_diff = dataset_m2['Intensity_MeanIntensity_Green'].mean() - dataset_m1['Intensity_MeanIntensity_Green'].mean()
        results.append((current_images, mean_diff, t_statistic, p_value))
        
t_test_results = pd.DataFrame(results, columns=['Image', 'mean_diff (M2 - M1)', 't_statistic', 'p_value'])
t_test_results[t_test_results['p_value'] < 0.05].sort_values(by='p_value')
# Out:
#        Image  mean_diff (M2 - M1)  t_statistic       p_value
# 6  M1_3_M2_4            -0.021318     8.316698  1.612104e-15
# 8  M1_3_M2_6            -0.013635     3.172683  1.634598e-03
# 7  M1_3_M2_5            -0.012648     2.818859  5.089662e-03

# %%
# change image numbers assigned by cellprofiler to cell type names
dataset.loc[dataset['ImageNumber'].isin([1, 2, 3]), 'CellType'] = 'M1'
dataset.loc[dataset['ImageNumber'].isin([4, 5, 6]), 'CellType'] = 'M2'

# divide the data into two datasets - for M1 and M2 cells data
dataset_m1 = dataset[dataset['CellType'] == 'M1']
dataset_m2 = dataset[dataset['CellType'] == 'M2']

# %%
t_test_results = pd.DataFrame(columns=['Measurement', 'mean_diff (M1 - M2)', 't_statistic', 'p_value'])

for column in range(2, 17):
    column_name = dataset_m1.columns[column] 
    t_statistic, p_value = ttest_ind(dataset_m1[column_name], dataset_m2[column_name])
    mean_diff = dataset_m1[column_name].mean() - dataset_m2[column_name].mean()
    t_test_results.loc[column] = [column_name, mean_diff, t_statistic, p_value]

# %%
# statistically significant difference
t_test_results[t_test_results['p_value'] < 0.05]
# Out:
#                                 Measurement  mean_diff (M1 - M2)  t_statistic  \
# 2   Intensity_IntegratedIntensityEdge_Green             3.995536    17.281189
# 3       Intensity_IntegratedIntensity_Green            44.840088     9.798429
# 4    Intensity_LowerQuartileIntensity_Green             0.006768    17.435371
# 6          Intensity_MassDisplacement_Green             0.276730     5.639933
# 8              Intensity_MaxIntensity_Green             0.029282     4.919930
# 9         Intensity_MeanIntensityEdge_Green             0.005710    10.149016
# 10            Intensity_MeanIntensity_Green             0.006502     2.465084
# 12         Intensity_MinIntensityEdge_Green            -0.001981   -11.097568
# 13             Intensity_MinIntensity_Green            -0.002678   -19.107848
#
#          p_value
# 2   1.107703e-58
# 3   1.067098e-21
# 4   1.413797e-59
# 6   2.219059e-08
# 8   1.013413e-06
# 9   4.312532e-23
# 10  1.386693e-02
# 12  4.707538e-27
# 13  1.583627e-69

# %%
# not statistically significant difference
t_test_results[t_test_results['p_value'] >= 0.05]
# Out:
#                                Measurement  mean_diff (M1 - M2)  t_statistic  \
# 5             Intensity_MADIntensity_Green             0.002046     1.541011
# 7         Intensity_MaxIntensityEdge_Green             0.006626     1.394073
# 11         Intensity_MedianIntensity_Green             0.004733     1.424425
# 14        Intensity_StdIntensityEdge_Green             0.000332     0.243905
# 15            Intensity_StdIntensity_Green             0.001786     0.717083
# 16  Intensity_UpperQuartileIntensity_Green             0.007324     1.488628
#
#      p_value
# 5   0.123634
# 7   0.163608
# 11  0.154639
# 14  0.807355
# 15  0.473492
# 16  0.136904

# %%
dataset_m1.describe()
# Out:
#        ImageNumber  ObjectNumber  Intensity_IntegratedIntensityEdge_Green  \
# count   386.000000    386.000000                               386.000000
# mean      2.106218     69.626943                                11.034995
# std       0.877785     44.407566                                 4.447817
# min       1.000000      1.000000                                 3.182409
# 25%       1.000000     33.000000                                 7.977769
# 50%       2.000000     65.000000                                10.155398
# 75%       3.000000    102.750000                                13.320708
# max       3.000000    171.000000                                27.393800
#
#        Intensity_IntegratedIntensity_Green  \
# count                           386.000000
# mean                            114.339035
# std                              89.049585
# min                              13.540248
# 25%                              59.178388
# 50%                              93.294604
# 75%                             143.265143
# max                             909.067386
#
#        Intensity_LowerQuartileIntensity_Green  Intensity_MADIntensity_Green  \
# count                              386.000000                    386.000000
# mean                                 0.044923                      0.013544
# std                                  0.008787                      0.003542
# min                                  0.028620                      0.007155
# 25%                                  0.037037                      0.011505
# 50%                                  0.042931                      0.014310
# 75%                                  0.051347                      0.014310
# max                                  0.068463                      0.025815
#
#        Intensity_MassDisplacement_Green  Intensity_MaxIntensityEdge_Green  \
# count                        386.000000                        386.000000
# mean                           0.772631                          0.094470
# std                            0.788195                          0.020386
# min                            0.031829                          0.060046
# 25%                            0.336494                          0.077162
# 50%                            0.590206                          0.091472
# 75%                            1.013135                          0.105782
# max                           11.665972                          0.171722
#
#        Intensity_MaxIntensity_Green  Intensity_MeanIntensityEdge_Green  ...  \
# count                    386.000000                         386.000000  ...
# mean                       0.160432                           0.047725  ...
# std                        0.058792                           0.008078  ...
# min                        0.088667                           0.032682  ...
# 25%                        0.125704                           0.040320  ...
# 50%                        0.154324                           0.042867  ...
# 75%                        0.186033                           0.055460  ...
# max                        1.000000                           0.068851  ...
#
#        Location_CenterMassIntensity_X_Green  \
# count                            386.000000
# mean                             482.918351
# std                              263.416814
# min                               26.004224
# 25%                              267.408300
# 50%                              470.322342
# 75%                              700.710503
# max                             1001.039795
#
#        Location_CenterMassIntensity_Y_Green  \
# count                            386.000000
# mean                             507.157112
# std                              277.019644
# min                               23.582407
# 25%                              260.875037
# 50%                              507.857826
# 75%                              737.406115
# max                              999.752834
#
#        Location_CenterMassIntensity_Z_Green  Location_Center_X  \
# count                                 386.0         386.000000
# mean                                    0.0         482.937592
# std                                     0.0         263.441964
# min                                     0.0          26.205508
# 25%                                     0.0         267.754469
# 50%                                     0.0         470.251768
# 75%                                     0.0         701.057827
# max                                     0.0        1001.092105
#
#        Location_Center_Y  Location_Center_Z  Location_MaxIntensity_X_Green  \
# count         386.000000              386.0                     386.000000
# mean          507.136476                0.0                     482.316062
# std           276.887410                0.0                     263.916985
# min            22.891076                0.0                      24.000000
# 25%           261.310059                0.0                     265.500000
# 50%           507.577765                0.0                     472.500000
# 75%           737.365598                0.0                     695.750000
# max           999.803526                0.0                    1007.000000
#
#        Location_MaxIntensity_Y_Green  Location_MaxIntensity_Z_Green  \
# count                     386.000000                          386.0
# mean                      506.186528                            0.0
# std                       278.077951                            0.0
# min                        28.000000                            0.0
# 25%                       254.250000                            0.0
# 50%                       505.500000                            0.0
# 75%                       740.500000                            0.0
# max                       999.000000                            0.0
#
#        Number_Object_Number
# count            386.000000
# mean              69.626943
# std               44.407566
# min                1.000000
# 25%               33.000000
# 50%               65.000000
# 75%              102.750000
# max              171.000000
#
# [8 rows x 27 columns]

# %%
dataset_m2.describe()
# Out:
#        ImageNumber  ObjectNumber  Intensity_IntegratedIntensityEdge_Green  \
# count   606.000000    606.000000                               606.000000
# mean      4.990099    101.831683                                 7.039459
# std       0.833137     58.918726                                 2.835054
# min       4.000000      1.000000                                 1.724160
# 25%       4.000000     51.000000                                 5.192246
# 50%       5.000000    101.500000                                 6.407313
# 75%       6.000000    152.000000                                 8.354467
# max       6.000000    213.000000                                26.424206
#
#        Intensity_IntegratedIntensity_Green  \
# count                           606.000000
# mean                             69.498946
# std                              55.085650
# min                              14.442899
# 25%                              38.365591
# 50%                              55.947398
# 75%                              84.839700
# max                             520.002703
#
#        Intensity_LowerQuartileIntensity_Green  Intensity_MADIntensity_Green  \
# count                              606.000000                    606.000000
# mean                                 0.038155                      0.011497
# std                                  0.003002                      0.025933
# min                                  0.025532                      0.000000
# 25%                                  0.037037                      0.008699
# 50%                                  0.037037                      0.008699
# 75%                                  0.039842                      0.011505
# max                                  0.045736                      0.418893
#
#        Intensity_MassDisplacement_Green  Intensity_MaxIntensityEdge_Green  \
# count                        606.000000                        606.000000
# mean                           0.495901                          0.087844
# std                            0.730486                          0.091937
# min                            0.011857                          0.034231
# 25%                            0.227375                          0.071551
# 50%                            0.384293                          0.077162
# 75%                            0.607626                          0.085089
# max                           14.821660                          1.000000
#
#        Intensity_MaxIntensity_Green  Intensity_MeanIntensityEdge_Green  ...  \
# count                    606.000000                         606.000000  ...
# mean                       0.131150                           0.042015  ...
# std                        0.107089                           0.008977  ...
# min                        0.077162                           0.025355  ...
# 25%                        0.105782                           0.039761  ...
# 50%                        0.117287                           0.041518  ...
# 75%                        0.125704                           0.042703  ...
# max                        1.000000                           0.169557  ...
#
#        Location_CenterMassIntensity_X_Green  \
# count                            606.000000
# mean                             500.327340
# std                              286.464425
# min                               21.562803
# 25%                              244.196821
# 50%                              505.076055
# 75%                              752.176105
# max                              998.292129
#
#        Location_CenterMassIntensity_Y_Green  \
# count                            606.000000
# mean                             565.300480
# std                              270.506491
# min                               19.265801
# 25%                              341.701484
# 50%                              607.832057
# 75%                              794.039535
# max                              999.614290
#
#        Location_CenterMassIntensity_Z_Green  Location_Center_X  \
# count                                 606.0         606.000000
# mean                                    0.0         500.315274
# std                                     0.0         286.471218
# min                                     0.0          21.940334
# 25%                                     0.0         243.869722
# 50%                                     0.0         505.113182
# 75%                                     0.0         752.258321
# max                                     0.0         998.449029
#
#        Location_Center_Y  Location_Center_Z  Location_MaxIntensity_X_Green  \
# count         606.000000              606.0                     606.000000
# mean          565.196251                0.0                     500.415842
# std           270.450144                0.0                     286.408404
# min            19.534364                0.0                      14.000000
# 25%           341.603512                0.0                     245.000000
# 50%           606.288135                0.0                     506.000000
# 75%           793.927298                0.0                     747.750000
# max           999.351585                0.0                    1000.000000
#
#        Location_MaxIntensity_Y_Green  Location_MaxIntensity_Z_Green  \
# count                     606.000000                          606.0
# mean                      566.212871                            0.0
# std                       270.878069                            0.0
# min                        13.000000                            0.0
# 25%                       340.250000                            0.0
# 50%                       609.500000                            0.0
# 75%                       796.750000                            0.0
# max                      1005.000000                            0.0
#
#        Number_Object_Number
# count            606.000000
# mean             101.831683
# std               58.918726
# min                1.000000
# 25%               51.000000
# 50%              101.500000
# 75%              152.000000
# max              213.000000
#
# [8 rows x 27 columns]
